# %%
import math as mt
import numpy as np
import matplotlib.pyplot as plt

N = np.arange(1,11,1)
time = np.arange(-mt.pi,mt.pi,0.001)

def s(t):
    return t/mt.pi

plt.plot(time, s(time))

# %%
arr1 = []

def summing(N,t):   
    
        ranger = np.arange(1,N+1,1)
        summer = 0
        
        for i in ranger:
            counter = (np.cos(i*mt.pi))*(np.sin(i*t))
            summer = summer + counter
        final = ((-2/mt.pi)*summer)
        return final
    
#for x in N:
plt.plot(time, s(time))
plt.plot(time,summing(5,time))

# %%
for x in N:
       plt.plot(time,summing(time))

# %%
def equation(N,t):
    summer = 0
    ranger = np.arange(1,N+1,1)

    for i in ranger:
            counter = (np.cos(i*mt.pi))*(np.sin(i*t))
            summer = summer + counter
            
    final = ((-2/mt.pi)*summer)
    return final

plt.plot(time,equation(2,time))

# %%
ranger = np.arange(1,3,1)
print(ranger)
# Out:
# [1 2]

# %%
for i in range(9):
    print (i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
