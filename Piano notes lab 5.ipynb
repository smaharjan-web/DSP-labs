# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.fftpack import fft
from scipy.io import wavfile

# %%
def doTheWork(inputAudio):
	#put whatever you want to be in the function here    
    fs, data = wavfile.read('kpt.wav')
    
    fftOut = fft(data)
    print(fftOut)
    
    time = len(data)/fs
    print(time)
    
    n = np.arange(len(data))
    T = 1/fs
    freqLabel = n/time
    
    plt.plot(freqLabel,abs(fftOut),'g--')
    
    plt.xlabel('frequency (Hz)')
    plt.ylabel('amplitude')
    plt.title('Piano Note Analysis')
    plt.xlim(0,4000)
    

if __name__ == "__main__":
    doTheWork('kpt.wav')
# Out:
# [164627.             +0.j         348493.77695077+136178.43383307j
#  185904.48777604+123702.0620046j  ... 282015.81618915 -18672.37449742j
#  185904.48777604-123702.0620046j  348493.77695077-136178.43383307j]
# 12.72453514739229

# %%
def doTheWork(inputAudio):
	#put whatever you want to be in the function here    
    fs, data = wavfile.read('hkp.wav')
    fftOut = fft(data)
    time = len(data)/fs
    
    n = np.arange(len(data))
    T = 1/fs
    freqLabel = n/time
    plt.plot(freqLabel,abs(fftOut),'g--')
    plt.xlabel('frequency (Hz)')
    plt.ylabel('amplitude')
    plt.title('Piano Note Analysis')
    plt.xlim(0,4000)
    print(time)


if __name__ == "__main__":
    doTheWork('hkp.wav')
# Out:
# 12.72453514739229
